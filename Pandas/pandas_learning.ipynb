# %% [markdown]
# ## Pandas Basics

# %% [markdown]
# - Pandas is an open source data analysis library written in python.
# - It leverage power and speed of Numpy to make data analysis and preprocessing easy for data scientist.
# - It provides rich and highly robust data operation.

# %%
import numpy as np
import pandas as pd

# %%
dict1 = {
    "name": ["Rohit" , "Rohan", "Shivam", "Rahul"],
    "marks": [90, 80, 70, 60],
    "city": ["Delhi", "Mumbai", "Chennai", "Kolkata"]
}

# %%
df = pd.DataFrame(dict1)
df
# Out:
#      name  marks     city
# 0   Rohit     90    Delhi
# 1   Rohan     80   Mumbai
# 2  Shivam     70  Chennai
# 3   Rahul     60  Kolkata

# %%
## Exporting data
df.to_csv("test_export_data.csv")
df.to_csv("test_export_data_index_false.csv", index=False)

# %%
## Show top rows
df.head(2)
# Out:
#     name  marks    city
# 0  Rohit     90   Delhi
# 1  Rohan     80  Mumbai

# %%
## Show bottom rows
df.tail(2)
# Out:
#      name  marks     city
# 2  Shivam     70  Chennai
# 3   Rahul     60  Kolkata

# %%
## Calculate statistics for numeric columns
df.describe()
# Out:
#            marks
# count   4.000000
# mean   75.000000
# std    12.909944
# min    60.000000
# 25%    67.500000
# 50%    75.000000
# 75%    82.500000
# max    90.000000

# %% [markdown]
# ## Data Structures
# #### There are two data structures in pandas.
# - ### Series
#     - Series are One Dimensional DataStructure
# - ### Dataframe
#     - Dataframe are Two Dimensional DataStructure

# %% [markdown]
# ### Series

# %%
ser = pd.Series(np.random.rand(34))
type(ser) # pandas.core.series.Series
ser
# Out:
# 0     0.554235
# 1     0.151746
# 2     0.951121
# 3     0.971143
# 4     0.982592
# 5     0.238297
# 6     0.001768
# 7     0.213459
# 8     0.964155
# 9     0.989071
# 10    0.482846
# 11    0.828251
# 12    0.937719
# 13    0.537490
# 14    0.716414
# 15    0.803144
# 16    0.456667
# 17    0.880145
# 18    0.553513
# 19    0.975251
# 20    0.964290
# 21    0.347442
# 22    0.241811
# 23    0.502474
# 24    0.991426
# 25    0.438290
# 26    0.984663
# 27    0.789856
# 28    0.188762
# 29    0.915214
# 30    0.606336
# 31    0.475068
# 32    0.422394
# 33    0.033884
# dtype: float64

# %% [markdown]
# ### DataFrame

# %%
df = pd.DataFrame(np.random.rand(334, 5), index = np.arange(334))
df
# Out:
#             0         1         2         3         4
# 0    0.542409  0.739883  0.645308  0.866934  0.138324
# 1    0.058592  0.788724  0.448219  0.780150  0.694355
# 2    0.677126  0.886942  0.745726  0.303671  0.383139
# 3    0.748780  0.660499  0.574413  0.149298  0.088586
# 4    0.300162  0.014201  0.713316  0.916894  0.264554
# ..        ...       ...       ...       ...       ...
# 329  0.677180  0.099890  0.058242  0.120966  0.185845
# 330  0.962762  0.102247  0.505363  0.156890  0.366747
# 331  0.275290  0.358608  0.900146  0.445781  0.659336
# 332  0.786493  0.147515  0.211548  0.685722  0.366693
# 333  0.561040  0.232325  0.839265  0.752938  0.728372
#
# [334 rows x 5 columns]

# %%
df.columns = ["A", "B", "C", "D", "E"]
df
# Out:
#             A         B         C         D         E
# 0    0.542409  0.739883  0.645308  0.866934  0.138324
# 1    0.058592  0.788724  0.448219  0.780150  0.694355
# 2    0.677126  0.886942  0.745726  0.303671  0.383139
# 3    0.748780  0.660499  0.574413  0.149298  0.088586
# 4    0.300162  0.014201  0.713316  0.916894  0.264554
# ..        ...       ...       ...       ...       ...
# 329  0.677180  0.099890  0.058242  0.120966  0.185845
# 330  0.962762  0.102247  0.505363  0.156890  0.366747
# 331  0.275290  0.358608  0.900146  0.445781  0.659336
# 332  0.786493  0.147515  0.211548  0.685722  0.366693
# 333  0.561040  0.232325  0.839265  0.752938  0.728372
#
# [334 rows x 5 columns]

# %%
## Accessing rows
df.loc[3]
# Out:
# A    0.748780
# B    0.660499
# C    0.574413
# D    0.149298
# E    0.088586
# Name: 3, dtype: float64

# %%
## Accessing columns
df["A"]
# Out:
# 0      0.542409
# 1      0.058592
# 2      0.677126
# 3      0.748780
# 4      0.300162
#          ...
# 329    0.677180
# 330    0.962762
# 331    0.275290
# 332    0.786493
# 333    0.561040
# Name: A, Length: 334, dtype: float64

# %%
## Accessing rows and columns with custom index
df.loc[[1, 2, 3], ["A", "B"]]
# Out:
#           A         B
# 1  0.058592  0.788724
# 2  0.677126  0.886942
# 3  0.748780  0.660499

# %%
df.loc[[1,2], :]
# Out:
#           A         B         C         D         E
# 1  0.058592  0.788724  0.448219  0.780150  0.694355
# 2  0.677126  0.886942  0.745726  0.303671  0.383139

# %%
df.loc[(df["A"] > 0.5)]
# Out:
#             A         B         C         D         E
# 0    0.542409  0.739883  0.645308  0.866934  0.138324
# 2    0.677126  0.886942  0.745726  0.303671  0.383139
# 3    0.748780  0.660499  0.574413  0.149298  0.088586
# 6    0.920416  0.290432  0.735729  0.307730  0.905701
# 8    0.513918  0.124224  0.341602  0.529404  0.314646
# ..        ...       ...       ...       ...       ...
# 328  0.773441  0.055141  0.113252  0.305231  0.562487
# 329  0.677180  0.099890  0.058242  0.120966  0.185845
# 330  0.962762  0.102247  0.505363  0.156890  0.366747
# 332  0.786493  0.147515  0.211548  0.685722  0.366693
# 333  0.561040  0.232325  0.839265  0.752938  0.728372
#
# [175 rows x 5 columns]

# %%
df.loc[df["A"] > 0.5, ["A"]]
# Out:
#             A
# 0    0.542409
# 2    0.677126
# 3    0.748780
# 6    0.920416
# 8    0.513918
# ..        ...
# 328  0.773441
# 329  0.677180
# 330  0.962762
# 332  0.786493
# 333  0.561040
#
# [175 rows x 1 columns]

# %%
df.loc(df["A"])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_10544\1844221528.py in ?()
# ----> 1 df.loc(df["A"])
#
# d:\python\.venv\lib\site-packages\pandas\core\indexing.py in ?(self, axis)
#     734         # we need to return a copy of ourselves
#     735         new_self = type(self)(self.name, self.obj)
#     736
#     737         if axis is not None:
# --> 738             axis_int_none = self.obj._get_axis_number(axis)
#     739         else:
#     740             axis_int_none = axis
#     741         new_self.axis = axis_int_none
#
# d:\python\.venv\lib\site-packages\pandas\core\generic.py in ?(cls, axis)
#     573     @classmethod
#     574     def _get_axis_number(cls, axis: Axis) -> AxisInt:
#     575         try:
#     576             return cls._AXIS_TO_AXIS_NUMBER[axis]
# --> 577         except KeyError:
#     578             raise ValueError(f"No axis named {axis} for object type {cls.__name__}")
#
# TypeError: unhashable type: 'Series'
